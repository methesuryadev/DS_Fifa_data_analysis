# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv(f'E:/DATA SCIENCE/starter/starter/archive/players_20.csv')
data.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
data.shape
# Out:
# (18278, 104)

# %%
data.ndim
# Out:
# 2

# %%
for d_type in data.dtypes:
    print(d_type)
# Out:
# int64
# object
# object
# object
# int64
# object
# int64
# int64
# object
# object
# int64
# int64
# int64
# int64
# object
# object
# int64
# int64
# int64
# object
# object
# object
# float64
# object
# object
# float64
# object
# object
# float64
# object
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# object
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object

# %%
for colm in data.columns:
    print(colm)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
data['nationality'].value_counts()
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: nationality, Length: 162, dtype: int64

# %%
data['nationality'].value_counts()[0:10]
# Out:
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: nationality, dtype: int64

# %%
data['nationality'].value_counts()[0:5]
# Out:
# England      1667
# Germany      1216
# Spain        1035
# France        984
# Argentina     886
# Name: nationality, dtype: int64

# %%
data['nationality'].value_counts()[0:5].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina'], dtype='object')

# %%
data['nationality'].value_counts()[0:5].plot.bar()
# Out:
# <AxesSubplot:>

# %%
player_salary=data[['short_name','wage_eur']].sort_values(by='wage_eur',ascending=False)
player_salary.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000

# %%
player_salary[0:5].plot.bar()
# Out:
# <AxesSubplot:>

# %%
indian_player=data[data['nationality']=='India']
indian_player.head()
# Out:
#        sofifa_id                                         player_url  \
# 12155     251742  https://sofifa.com/player/251742/gajodara-chat...
# 13102     251723  https://sofifa.com/player/251723/prakul-bhatt/...
# 13103     251728  https://sofifa.com/player/251728/bhadrashree-r...
# 13970     251722  https://sofifa.com/player/251722/abhimoda-chak...
# 13971     251727  https://sofifa.com/player/251727/hantidev-bhan...
#
#            short_name             long_name  age         dob  height_cm  \
# 12155   G. Chatterjee   Gajodara Chatterjee   33  1985-07-04        195
# 13102        P. Bhatt          Prakul Bhatt   34  1985-04-07        182
# 13103          B. Raj       Bhadrashree Raj   31  1988-03-25        175
# 13970  A. Chakraborty  Abhimoda Chakraborty   33  1985-10-27        189
# 13971     H. Bhandari     Hantidev Bhandari   30  1989-06-22        178
#
#        weight_kg nationality   club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# ...

# %%
indian_player.sort_values(by='height_cm',ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 12155     251742  https://sofifa.com/player/251742/gajodara-chat...
# 13970     251722  https://sofifa.com/player/251722/abhimoda-chak...
# 16303     251733  https://sofifa.com/player/251733/palkesh-nagar...
# 15205     251747  https://sofifa.com/player/251747/anuvinda-khur...
# 15866     251726  https://sofifa.com/player/251726/diasha-sundar...
#
#            short_name             long_name  age         dob  height_cm  \
# 12155   G. Chatterjee   Gajodara Chatterjee   33  1985-07-04        195
# 13970  A. Chakraborty  Abhimoda Chakraborty   33  1985-10-27        189
# 16303    P. Nagarajan     Palkesh Nagarajan   29  1989-10-12        189
# 15205      A. Khurana      Anuvinda Khurana   26  1993-04-21        186
# 15866     D. Sundaram       Diasha Sundaram   30  1989-04-28        186
#
#        weight_kg nationality   club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# ...

# %%
indian_player.sort_values(by='weight_kg',ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 16303     251733  https://sofifa.com/player/251733/palkesh-nagar...
# 12155     251742  https://sofifa.com/player/251742/gajodara-chat...
# 15867     251746  https://sofifa.com/player/251746/randhir-jayar...
# 15205     251747  https://sofifa.com/player/251747/anuvinda-khur...
# 15866     251726  https://sofifa.com/player/251726/diasha-sundar...
#
#           short_name            long_name  age         dob  height_cm  \
# 16303   P. Nagarajan    Palkesh Nagarajan   29  1989-10-12        189
# 12155  G. Chatterjee  Gajodara Chatterjee   33  1985-07-04        195
# 15867   R. Jayaraman    Randhir Jayaraman   34  1984-11-20        180
# 15205     A. Khurana     Anuvinda Khurana   26  1993-04-21        186
# 15866    D. Sundaram      Diasha Sundaram   30  1989-04-28        186
#
#        weight_kg nationality   club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# ...

# %%
indian_player[['short_name','wage_eur']].sort_values(by='wage_eur',ascending=False).head()
# Out:
#           short_name  wage_eur
# 12155  G. Chatterjee         0
# 15324    R. Nadkarni         0
# 16354       C. Palan         0
# 16353      A. Varkay         0
# 16352     T. Agarwal         0

# %%
player_shooting=data[['short_name','shooting']]
player_shooting.sort_values(by='shooting',ascending=False).head()
# Out:
#             short_name  shooting
# 1    Cristiano Ronaldo      93.0
# 0             L. Messi      92.0
# 12             H. Kane      91.0
# 17           S. Agüero      90.0
# 205    F. Quagliarella      89.0

# %%
player_defending=data[['short_name','defending','nationality','club']]
player_defending.sort_values(by='defending',ascending=False).head()
# Out:
#       short_name  defending  nationality               club
# 16  G. Chiellini       90.0        Italy           Juventus
# 7    V. van Dijk       90.0  Netherlands          Liverpool
# 11  K. Koulibaly       89.0      Senegal             Napoli
# 35      D. Godín       89.0      Uruguay              Inter
# 49    M. Hummels       89.0      Germany  Borussia Dortmund

# %%
real_madrid=data[data['club']=='Real Madrid']
real_madrid.head()
# Out:
#     sofifa_id                                         player_url  \
# 4      183277  https://sofifa.com/player/183277/eden-hazard/2...
# 8      177003  https://sofifa.com/player/177003/luka-modric/2...
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...
# 28     192119  https://sofifa.com/player/192119/thibaut-court...
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...
#
#       short_name            long_name  age         dob  height_cm  weight_kg  \
# 4      E. Hazard          Eden Hazard   28  1991-01-07        175         74
# 8      L. Modrić          Luka Modrić   33  1985-09-09        172         66
# 18  Sergio Ramos  Sergio Ramos García   33  1986-03-30        184         82
# 28   T. Courtois     Thibaut Courtois   27  1992-05-11        199         96
# 36      T. Kroos           Toni Kroos   29  1990-01-04        183         76
#
#    nationality         club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb  \
# ...

# %%
real_madrid[['short_name','wage_eur']].sort_values(by='wage_eur',ascending=False).head()
# Out:
#       short_name  wage_eur
# 4      E. Hazard    470000
# 8      L. Modrić    340000
# 36      T. Kroos    330000
# 18  Sergio Ramos    300000
# 46    K. Benzema    285000

# %%
real_madrid[['short_name','shooting']].sort_values(by='shooting',ascending=False).head()
# Out:
#        short_name  shooting
# 100       G. Bale      87.0
# 106  J. Rodríguez      86.0
# 4       E. Hazard      83.0
# 46     K. Benzema      82.0
# 161      L. Jović      82.0

# %%
real_madrid[['short_name','defending']].sort_values(by='defending',ascending=False).head()
# Out:
#        short_name  defending
# 18   Sergio Ramos       87.0
# 42       Casemiro       85.0
# 76      R. Varane       85.0
# 94       Carvajal       82.0
# 332  Éder Militão       81.0

# %%
real_madrid['nationality'].value_counts()
# Out:
# Spain                 13
# Brazil                 6
# France                 3
# Belgium                2
# Croatia                1
# Germany                1
# Costa Rica             1
# Wales                  1
# Colombia               1
# Serbia                 1
# Dominican Republic     1
# Uruguay                1
# Japan                  1
# Name: nationality, dtype: int64
